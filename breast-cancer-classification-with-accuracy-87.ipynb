# %%
#@title Default title text
# Import Libraries
import pandas as pd
from sklearn.impute import SimpleImputer
import numpy as np
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import chi2 , f_classif 
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
#----------------------------------------------------
#reading data
data = pd.read_csv('../input/breast-cancer-wisconsin-data/data.csv')

data.describe()

#X Data
X = data.drop(['diagnosis'], axis=1, inplace=False)
print('X Data is \n' , X.head())
print('X shape is ' , X.shape)

#y Data
y = data['diagnosis']
print('y Data is \n' , y.head())
print('y shape is ' , y.shape)

#----------------------------------------------------
# Cleaning data

'''
impute.SimpleImputer(missing_values=nan, strategy='mean’, fill_value=None, verbose=0, copy=True)
'''


ImputedModule = SimpleImputer(missing_values = np.nan, strategy ='most_frequent')
ImputedX = ImputedModule.fit(X)
X = ImputedX.transform(X)


#X Data
print('X Data is \n' , X[:570])

#y Data
print('y Data is \n' , y[:570])

#----------------------------------------------------
#Feature Selection by Percentile
print('Original X Shape is ' , X.shape)
FeatureSelection = SelectPercentile(score_func = chi2, percentile=20) # score_func can = f_classif
X = FeatureSelection.fit_transform(X, y)

#showing X Dimension 
print('X Shape is ' , X.shape)
print('Selected Features are : ' , FeatureSelection.get_support())

#----------------------------------------------------
#Normalizing Data

scaler = Normalizer(copy=True, norm='l2') # you can change the norm to 'l1' or 'max' 
X = scaler.fit_transform(X)

#showing data
print('X \n' , X[:570])
print('y \n' , y[:570])

#----------------------------------------------------
#Splitting data

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44, shuffle =True)

#Splitted Data
print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)

#----------------------------------------------------
#Applying RandomForestClassifier Model 

'''
ensemble.RandomForestClassifier(n_estimators='warn’, criterion=’gini’, max_depth=None,
                                min_samples_split=2, min_samples_leaf=1,min_weight_fraction_leaf=0.0,
                                max_features='auto’,max_leaf_nodes=None,min_impurity_decrease=0.0,
                                min_impurity_split=None, bootstrap=True,oob_score=False, n_jobs=None,
                                random_state=None, verbose=0,warm_start=False, class_weight=None)
'''

RandomForestClassifierModel = RandomForestClassifier(criterion = 'gini',n_estimators=100,max_depth=2,random_state=33) #criterion can be also : entropy 
RandomForestClassifierModel.fit(X_train, y_train)

#Calculating Details
print('RandomForestClassifierModel Train Score is : ' , RandomForestClassifierModel.score(X_train, y_train))
print('RandomForestClassifierModel Test Score is : ' , RandomForestClassifierModel.score(X_test, y_test))
print('RandomForestClassifierModel features importances are : ' , RandomForestClassifierModel.feature_importances_)
print('----------------------------------------------------')

#Calculating Prediction
y_pred = RandomForestClassifierModel.predict(X_test)
y_pred_prob = RandomForestClassifierModel.predict_proba(X_test)
print('Predicted Value for RandomForestClassifierModel is : ' , y_pred[:570])
print('Prediction Probabilities Value for RandomForestClassifierModel is : ' , y_pred_prob[:570])

#----------------------------------------------------
#Applying DecisionTreeClassifier Model 

'''
sklearn.tree.DecisionTreeClassifier(criterion='gini’, splitter=’best’, max_depth=None,min_samples_split=2,
                                    min_samples_leaf=1,min_weight_fraction_leaf=0.0,max_features=None,
                                    random_state=None, max_leaf_nodes=None,min_impurity_decrease=0.0,
                                    min_impurity_split=None, class_weight=None,presort=False)
'''

DecisionTreeClassifierModel = DecisionTreeClassifier(criterion='gini',max_depth=3,random_state=33) #criterion can be entropy
DecisionTreeClassifierModel.fit(X_train, y_train)

#Calculating Details
print('DecisionTreeClassifierModel Train Score is : ' , DecisionTreeClassifierModel.score(X_train, y_train))
print('DecisionTreeClassifierModel Test Score is : ' , DecisionTreeClassifierModel.score(X_test, y_test))
print('DecisionTreeClassifierModel Classes are : ' , DecisionTreeClassifierModel.classes_)
print('DecisionTreeClassifierModel feature importances are : ' , DecisionTreeClassifierModel.feature_importances_)
print('----------------------------------------------------')

#Calculating Prediction
y_pred = DecisionTreeClassifierModel.predict(X_test)
y_pred_prob = DecisionTreeClassifierModel.predict_proba(X_test)
print('Predicted Value for DecisionTreeClassifierModel is : ' , y_pred[:570])
print('Prediction Probabilities Value for DecisionTreeClassifierModel is : ' , y_pred_prob[:570])

#----------------------------------------------------
#Calculating Accuracy Score  : ((TP + TN) / float(TP + TN + FP + FN))
AccScore = accuracy_score(y_test, y_pred, normalize=False)
print('Accuracy Score is : ', AccScore)

#----------------------------------------------------
#Calculating F1 Score  : 2 * (precision * recall) / (precision + recall)
# f1_score(y_true, y_pred, labels=None, pos_label=1, average=’binary’, sample_weight=None)

F1Score = f1_score(y_test, y_pred, average='micro') #it can be : binary,macro,weighted,samples
print('F1 Score is : ', F1Score)
# Out:
# X Data is
#           id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        17.99         10.38          122.80     1001.0
# 1    842517        20.57         17.77          132.90     1326.0
# 2  84300903        19.69         21.25          130.00     1203.0
# 3  84348301        11.42         20.38           77.58      386.1
# 4  84358402        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0          0.4601                  0.11890          NaN
# 1          0.2750                  0.08902          NaN
# 2          0.3613                  0.08758          NaN
# 3          0.6638                  0.17300          NaN
# 4          0.2364                  0.07678          NaN
#
# [5 rows x 32 columns]
# X shape is  (569, 32)
# y Data is
#  0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object
# y shape is  (569,)
# X Data is
#  [[8.4230200e+05 1.7990000e+01 1.0380000e+01 ... 2.6540000e-01
#   4.6010000e-01 1.1890000e-01]
#  [8.4251700e+05 2.0570000e+01 1.7770000e+01 ... 1.8600000e-01
#   2.7500000e-01 8.9020000e-02]
#  [8.4300903e+07 1.9690000e+01 2.1250000e+01 ... 2.4300000e-01
#   3.6130000e-01 8.7580000e-02]
#  ...
#  [9.2695400e+05 1.6600000e+01 2.8080000e+01 ... 1.4180000e-01
#   2.2180000e-01 7.8200000e-02]
#  [9.2724100e+05 2.0600000e+01 2.9330000e+01 ... 2.6500000e-01
#   4.0870000e-01 1.2400000e-01]
#  [9.2751000e+04 7.7600000e+00 2.4540000e+01 ... 0.0000000e+00
#   2.8710000e-01 7.0390000e-02]]
# y Data is
#  0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object
# Original X Shape is  (569, 31)
# X Shape is  (569, 6)
# Selected Features are :  [ True False False  True  True False False False False False False False
#  False False  True False False False False False False False False  True
#   True False False False False False False]
# X
#  [[9.99996370e-01 1.45790410e-04 1.18840554e-03 1.82119291e-04
#   2.19160503e-04 2.39699380e-03]
#  [9.99996032e-01 1.57740998e-04 1.57384924e-03 8.79266603e-05
#   1.88482096e-04 2.32160566e-03]
#  [1.00000000e+00 1.54209499e-06 1.42703098e-05 1.11540917e-06
#   1.80899604e-06 2.02726180e-05]
#  ...
#  [9.99998819e-01 1.16834139e-04 9.25719061e-04 5.23757842e-05
#   1.36684075e-04 1.21257222e-03]
#  [9.99997105e-01 1.51092968e-04 1.36425842e-03 9.29852654e-05
#   1.99084667e-04 1.96388504e-03]
#  [9.99993545e-01 5.16648776e-04 1.95144884e-03 2.06465444e-04
#   6.37832671e-04 2.89590696e-03]]
# y
#  0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object
# X_train shape is  (381, 6)
# X_test shape is  (188, 6)
# y_train shape is  (381,)
# y_test shape is  (188,)
# RandomForestClassifierModel Train Score is :  0.8110236220472441
# RandomForestClassifierModel Test Score is :  0.7978723404255319
# RandomForestClassifierModel features importances are :  [0.02702104 0.20543246 0.16984014 0.04327086 0.33477024 0.21966526]
# ----------------------------------------------------
# Predicted Value for RandomForestClassifierModel is :  ['M' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'B'
#  'M' 'B' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B'
#  'B' 'B' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M']
# Prediction Probabilities Value for RandomForestClassifierModel is :  [[0.27740378 0.72259622]
#  [0.57719119 0.42280881]
#  [0.9234727  0.0765273 ]
#  [0.0883427  0.9116573 ]
#  [0.72682086 0.27317914]
#  [0.89804301 0.10195699]
#  [0.9234727  0.0765273 ]
#  [0.11805494 0.88194506]
#  [0.09158674 0.90841326]
#  [0.9109597  0.0890403 ]
#  [0.65263983 0.34736017]
#  [0.65971482 0.34028518]
#  [0.65971482 0.34028518]
#  [0.65971482 0.34028518]
#  [0.65971482 0.34028518]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.0883427  0.9116573 ]
#  [0.28551168 0.71448832]
#  [0.65971482 0.34028518]
#  [0.9234727  0.0765273 ]
#  [0.65971482 0.34028518]
#  [0.89706923 0.10293077]
#  [0.9234727  0.0765273 ]
#  [0.57719119 0.42280881]
#  [0.65971482 0.34028518]
#  [0.61981652 0.38018348]
#  [0.65971482 0.34028518]
#  [0.0883427  0.9116573 ]
#  [0.92030209 0.07969791]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.84378189 0.15621811]
#  [0.9234727  0.0765273 ]
#  [0.57719119 0.42280881]
#  [0.90676641 0.09323359]
#  [0.83922465 0.16077535]
#  [0.9234727  0.0765273 ]
#  [0.57719119 0.42280881]
#  [0.9234727  0.0765273 ]
#  [0.61981652 0.38018348]
#  [0.9234727  0.0765273 ]
#  [0.1491825  0.8508175 ]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.61981652 0.38018348]
#  [0.65971482 0.34028518]
#  [0.61981652 0.38018348]
#  [0.9234727  0.0765273 ]
#  [0.61981652 0.38018348]
#  [0.92030209 0.07969791]
#  [0.65971482 0.34028518]
#  [0.9234727  0.0765273 ]
#  [0.62764169 0.37235831]
#  [0.27670013 0.72329987]
#  [0.65971482 0.34028518]
#  [0.65621392 0.34378608]
#  [0.90388629 0.09611371]
#  [0.92030209 0.07969791]
#  [0.65971482 0.34028518]
#  [0.9234727  0.0765273 ]
#  [0.0883427  0.9116573 ]
#  [0.9234727  0.0765273 ]
#  [0.09038948 0.90961052]
#  [0.89804301 0.10195699]
#  [0.91413031 0.08586969]
#  [0.90304991 0.09695009]
#  [0.31080524 0.68919476]
#  [0.57719119 0.42280881]
#  [0.61981652 0.38018348]
#  [0.65621392 0.34378608]
#  [0.0883427  0.9116573 ]
#  [0.0883427  0.9116573 ]
#  [0.9234727  0.0765273 ]
#  [0.40848238 0.59151762]
#  [0.65971482 0.34028518]
#  [0.9234727  0.0765273 ]
#  [0.9234727  0.0765273 ]
#  [0.65621392 0.34378608]
#  [0.64377704 0.35622296]
#  [0.65971482 0.34028518]
#  [0.65067565 0.34932435]
#  [0.65971482 0.34028518]
#  [0.72160249 0.27839751]
#  [0.0883427  0.9116573 ]]
# DecisionTreeClassifierModel Train Score is :  0.8871391076115486
# DecisionTreeClassifierModel Test Score is :  0.8723404255319149
# DecisionTreeClassifierModel Classes are :  ['B' 'M']
# DecisionTreeClassifierModel feature importances are :  [0.         0.13206993 0.         0.08296798 0.78496209 0.        ]
# ----------------------------------------------------
# Predicted Value for DecisionTreeClassifierModel is :  ['M' 'M' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M'
#  'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M'
#  'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'B' 'M' 'M' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M'
#  'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'M' 'B' 'M' 'M' 'B' 'M' 'B' 'M' 'M'
#  'M' 'B' 'M' 'M' 'M' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M'
#  'B' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'B'
#  'B' 'B' 'M' 'M' 'M' 'B' 'B' 'M' 'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M' 'M' 'B'
#  'M' 'B' 'M' 'M' 'M' 'B' 'B' 'B' 'M' 'B' 'B' 'B' 'M' 'M' 'B' 'M' 'M' 'B'
#  'B' 'B' 'B' 'B' 'B' 'B' 'B' 'M']
# Prediction Probabilities Value for DecisionTreeClassifierModel is :  [[0.01388889 0.98611111]
#  [0.16666667 0.83333333]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.5        0.5       ]
#  [0.74257426 0.25742574]
#  [0.         1.        ]
#  [0.         1.        ]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.40909091 0.59090909]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.94444444 0.05555556]
#  [0.         1.        ]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.94444444 0.05555556]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.94444444 0.05555556]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.40909091 0.59090909]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.         1.        ]
#  [0.01388889 0.98611111]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.         1.        ]
#  [0.94444444 0.05555556]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.94444444 0.05555556]
#  [0.01388889 0.98611111]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.40909091 0.59090909]
#  [0.         1.        ]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.16666667 0.83333333]
#  [0.01388889 0.98611111]
#  [0.01388889 0.98611111]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.         1.        ]
#  [0.01388889 0.98611111]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.16666667 0.83333333]
#  [0.40909091 0.59090909]
#  [0.94444444 0.05555556]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.40909091 0.59090909]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.         1.        ]
#  [0.01388889 0.98611111]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.16666667 0.83333333]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]
#  [0.         1.        ]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.40909091 0.59090909]
#  [0.94444444 0.05555556]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.01388889 0.98611111]
#  [0.01388889 0.98611111]
#  [0.97777778 0.02222222]
#  [0.40909091 0.59090909]
#  [0.         1.        ]
#  [0.97777778 0.02222222]
#  [0.97777778 0.02222222]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.74257426 0.25742574]
#  [0.97777778 0.02222222]
#  [0.01388889 0.98611111]]
# Accuracy Score is :  164
# F1 Score is :  0.8723404255319149
